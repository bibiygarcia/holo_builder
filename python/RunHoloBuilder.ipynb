# %%
#!pip install pillow
#!pip install moviepy
#int(input("Enter the maximum base width (max_width in pixels): "))
# render_pyramid_3d(num_surfaces, max_width)

#!pip install pylint

# %%
#!pylint data_handler.py

# %%
#import warnings
#warnings.filterwarnings("ignore", category=UserWarning, module="moviepy")
from moviepy import VideoFileClip, ImageClip, concatenate_videoclips
#print(dir(VideoFileClip))

# %%
# HELPFUL FUNCTIONS FOR IMPROVING IMAGE/VIDEO
import os
from PIL import Image, ImageDraw, ImageOps
from image_manipulator import extract_frame, create_perfect_loop_videos

# %% [markdown]
# RESULTSDIR = '../results'  # Directory for dumping results
# DATADIR = '../data'  # Data directory
# SUBDIR= 'cosmetic_jar' # Data subdirectory for keeping labled images if use_duplicates is false
# NAMEDIR = "holoPyramid4Sided_0_Jar_Container_1280x720.mp4"
# NUM_SURFACES = 4 # number of surfaces the pyramid has
#
# filedir = os.path.join(DATADIR, SUBDIR, NAMEDIR)
# file_path = os.path.normpath(filedir)
# image0 = extract_frame(file_path, 0.0)
# image0.show()

# %% [markdown]
# filedir = os.path.join(DATADIR, SUBDIR, NAMEDIR)
# file_path = os.path.normpath(filedir)
# video_paths=create_perfect_loop_videos(file_path, NUM_SURFACES)

# %%
#OUTPUTDIR = holo_builder.main()
# %run holo_builder
# Out:
# Beginning Image Hologram Build...
#
# Fetching Screen Data...
#
# 	Displaying Fetch Results:
# 	Screen Width: 2560 px
# 	Screen Height: 1080 px
# 	DPI: 96.05 dpi
# 	Scaling Factor: 1.00
# 	Minimum Number of Pixels: 1080
#
# Retreiving Image Files...
#
# Calculating Pyramid Dimensions...
# 	Pyramid Dimensions:
# Slant Height(cm): 14.27344096026083
# Base Side Length(cm): 20.72292169045276
# Expected Pyramid Height(cm): 9.807588154854459
#
# Drawing Pyramid Base...
#
# Setting Alignment Dictionary...
#
# Building Composite Image...
# <PIL.Image.Image image mode=RGBA size=784x784>
# Composite Image Saved To ../results/holoPyramid5Sided_island1.png

# %% [markdown]
# if holo_builder.VIDEO_HOLOGRAM:
#     # Load the video file
#     #clip = VideoFileClip(OUTPUTDIR)
#     # Preview the video (opens the system's default media player)
#     #clip.preview()
#
# else:
#     pic = Image.open(OUTPUTDIR)
#     display(pic)
